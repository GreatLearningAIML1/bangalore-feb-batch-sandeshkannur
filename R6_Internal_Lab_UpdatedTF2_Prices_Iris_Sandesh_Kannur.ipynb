# %% [markdown]
# ## Linear Classifier in TensorFlow
# Using Low Level API in Eager Execution mode

# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf

# %%
#Enable Eager Execution if using tensflow version < 2.0
#From tensorflow v2.0 onwards, Eager Execution will be enabled by default

# %% [markdown]
# ### Collect Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data1 = pd.read_csv('/content/drive/My Drive/AIML/Residency6/prices.csv')

# %% [markdown]
# ### Check all columns in the dataset

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %% [markdown]
# ### Drop columns `date` and  `symbol`

# %%
Housing = data1.drop(['date','symbol'],axis=1)

# %%
Housing.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %% [markdown]
# ### Consider only first 1000 rows in the dataset for building feature set and target set
# Target 'Volume' has very high values. Divide 'Volume' by 1000,000

# %%
Housing['volume'] = Housing['volume'].apply(lambda x: x/1000000)

# %%
Housing.head()
# Out:
#          open       close         low        high  volume
# 0  123.430000  125.839996  122.309998  126.250000  2.1636
# 1  125.239998  119.980003  119.940002  125.540001  2.3864
# 2  116.379997  114.949997  114.930000  119.739998  2.4895
# 3  115.480003  116.620003  113.500000  117.440002  2.0063
# 4  117.010002  114.970001  114.089996  117.330002  1.4086

# %%
Housing1 = Housing.head(1000)

# %% [markdown]
# ### Divide the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
X =  Housing1.drop("volume", axis=1)
y =  Housing1.pop("volume")

xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=.3,random_state=4)

# %% [markdown]
# #### Convert Training and Test Data to numpy float32 arrays

# %%
import numpy as np
Xtrain = np.asarray(xtrain)
ytrain = np.asarray(ytrain)

# %% [markdown]
# ### Normalize the data
# You can use Normalizer from sklearn.preprocessing

# %%
from sklearn import preprocessing
X_normalized = preprocessing.normalize(X, norm='l2')

# %% [markdown]
# ## Building the Model in tensorflow

# %% [markdown]
# 1.Define Weights and Bias, use tf.zeros to initialize weights and Bias

# %%
#Input features
x = tf.placeholder(shape=[None,4],dtype=tf.float32, name='x-input')

#Normalize the data
x_n = tf.nn.l2_normalize(x,1) 

#Actual Prices
y_ = tf.placeholder(shape=[None],dtype=tf.float32, name='y-input')

W = tf.Variable(tf.zeros(shape=[4,1]), name="Weights")
b = tf.Variable(tf.zeros(shape=[1]),name="Bias")

# %% [markdown]
# 2.Define a function to calculate prediction

# %%
y = tf.add(tf.matmul(x_n,W),b,name='output') #X is normalized, hence X_n

# %% [markdown]
# 3.Loss (Cost) Function [Mean square error]

# %%
loss = tf.reduce_mean(tf.square(y-y_),name='Loss')

# %% [markdown]
# 4.Function to train the Model
#
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
train_op = tf.train.GradientDescentOptimizer(0.03).minimize(loss)

# %% [markdown]
# ## Train the model for 100 epochs
# 1. Observe the training loss at every iteration
# 2. Observe Train loss at every 5th iteration

# %%
#Lets start graph Execution
sess = tf.Session()

# variables need to be initialized before we can use them
sess.run(tf.global_variables_initializer())

#how many times data need to be shown to model
training_epochs = 100

# %%
for epoch in range(training_epochs):
            
    #Calculate train_op and loss
    _, train_loss = sess.run([train_op,loss],feed_dict={x:Xtrain, y_:ytrain}) # X and Y is like X_Train and Y_Train here.
    
    if epoch % 5 == 0:
        print ('Training loss at step: ', epoch, ' is ', train_loss)
# Out:
# ('Training loss at step: ', 0, ' is ', 222.06296)
# ('Training loss at step: ', 5, ' is ', 202.34476)
# ('Training loss at step: ', 10, ' is ', 196.85304)
# ('Training loss at step: ', 15, ' is ', 195.32355)
# ('Training loss at step: ', 20, ' is ', 194.89757)
# ('Training loss at step: ', 25, ' is ', 194.7789)
# ('Training loss at step: ', 30, ' is ', 194.7459)
# ('Training loss at step: ', 35, ' is ', 194.73668)
# ('Training loss at step: ', 40, ' is ', 194.7341)
# ('Training loss at step: ', 45, ' is ', 194.73341)
# ('Training loss at step: ', 50, ' is ', 194.73318)
# ('Training loss at step: ', 55, ' is ', 194.73314)
# ('Training loss at step: ', 60, ' is ', 194.73314)
# ('Training loss at step: ', 65, ' is ', 194.73312)
# ('Training loss at step: ', 70, ' is ', 194.73311)
# ('Training loss at step: ', 75, ' is ', 194.73312)
# ('Training loss at step: ', 80, ' is ', 194.73314)
# ('Training loss at step: ', 85, ' is ', 194.73314)
# ...

# %% [markdown]
# ### Get the shapes and values of W and b

# %%
print(W.shape)
print(b.shape)
# Out:
# (4, 1)
# (1,)

# %% [markdown]
# ### Model Prediction on 1st Examples in Test Dataset

# %%
test_loss = sess.run([loss],feed_dict={x:xtest, y_:ytest}) 
print ('Training loss at step:is ', test_loss)
# Out:
# ('Training loss at step:is ', [242.4668])

# %% [markdown]
# ## Classification using tf.Keras
#
# In this exercise, we will build a Deep Neural Network using tf.Keras. We will use Iris Dataset for this exercise.

# %% [markdown]
# ### Load the given Iris data using pandas (Iris.csv)

# %%
data = pd.read_csv('/content/drive/My Drive/AIML/Residency6/11_Iris.csv')

# %% [markdown]
# ### Target set has different categories. So, Label encode them. And convert into one-hot vectors using get_dummies in pandas.

# %%
new_data = pd.get_dummies(data,prefix=['Species'], columns=['Species'])

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
# Id                         150 non-null int64
# SepalLengthCm              150 non-null float64
# SepalWidthCm               150 non-null float64
# PetalLengthCm              150 non-null float64
# PetalWidthCm               150 non-null float64
# Species_Iris-setosa        150 non-null uint8
# Species_Iris-versicolor    150 non-null uint8
# Species_Iris-virginica     150 non-null uint8
# dtypes: float64(4), int64(1), uint8(3)
# memory usage: 6.4 KB

# %% [markdown]
# ### Splitting the data into feature set and target set

# %%
from sklearn.model_selection import train_test_split

X =  new_data.drop(['Id',"Species_Iris-setosa",'Species_Iris-versicolor',
       'Species_Iris-virginica'], axis=1)
y =  new_data[['Species_Iris-setosa', 'Species_Iris-versicolor',
       'Species_Iris-virginica']]
Xtrain,Xtest,ytrain,ytest = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# ###  Building Model in tf.keras
#
# Build a Linear Classifier model  <br>
# 1.  Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3<br>
# 2. Apply Softmax on Dense Layer outputs <br>
# 3. Use SGD as Optimizer
# 4. Use categorical_crossentropy as loss function

# %%
from sklearn.neural_network import MLPClassifier
model=MLPClassifier(hidden_layer_sizes=(4))
model.fit(Xtrain,ytrain)
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=4, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# ### Model Training

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(3, input_dim=4, kernel_initializer='normal', activation='softmax'))
#model.add(Dense(3, kernel_initializer='normal'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='SGD', metrics= ['accuracy'])
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0721 11:51:57.039491 140444500895616 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0721 11:51:57.042396 140444500895616 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0721 11:51:57.046483 140444500895616 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# ...

# %% [markdown]
# ### Model Prediction

# %%
model.fit(Xtrain, ytrain, validation_data=(Xtest,ytest), epochs=10, batch_size=5)
# evaluate the model
scores = model.evaluate(X, y)
# Out:
# W0721 11:51:57.187136 140444500895616 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_grad.py:1250: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0721 11:51:57.231597 140444500895616 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 105 samples, validate on 45 samples
# Epoch 1/10
# 105/105 [==============================] - 0s 2ms/step - loss: 0.9998 - acc: 0.4762 - val_loss: 0.9547 - val_acc: 0.6000
# Epoch 2/10
# 105/105 [==============================] - 0s 568us/step - loss: 0.8792 - acc: 0.6952 - val_loss: 0.8330 - val_acc: 0.6000
# Epoch 3/10
# ...

# %%
scores[1]*100
# Out:
# 85.33333333333334

# %% [markdown]
# ### Save the Model

# %%
model.save("model.dump")

# %% [markdown]
# ### Build and Train a Deep Neural network with 2 hidden layer  - Optional - For Practice
#
# Does it perform better than Linear Classifier? What could be the reason for difference in performance?
